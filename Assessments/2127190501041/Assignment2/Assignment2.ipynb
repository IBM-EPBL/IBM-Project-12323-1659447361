# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv('/content/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
import seaborn as sns

# %% [markdown]
# # Univariate Analysis

# %%
sns.countplot(df['Gender'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Bi-Variate Analysis

# %%
import matplotlib.pyplot as plt

# %%
x = df['CreditScore']
y = df['EstimatedSalary']
z = df['IsActiveMember']
a = df['Gender']

# %%
plt.plot(a,z,'r',marker='.')
plt.xlabel('Gender')
plt.ylabel('IsActiveMember')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
plt.bar(a,z)
# Out:
# <BarContainer object of 10000 artists>

# %% [markdown]
# # Muli-Variate Analysis

# %%
plt.bar(x,y,z)
# Out:
# <BarContainer object of 10000 artists>

# %% [markdown]
# # Descriptive statistics

# %%
a = df['EstimatedSalary']

# %%
df['Age'].mean()
# Out:
# 38.9218

# %%
df['Age'].mode()
# Out:
# 0    37
# dtype: int64

# %%
df['Age'].median()
# Out:
# 37.0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe(include='all')
# Out:
#           RowNumber    CustomerId Surname   CreditScore Geography Gender  \
# count   10000.00000  1.000000e+04   10000  10000.000000     10000  10000
# unique          NaN           NaN    2932           NaN         3      2
# top             NaN           NaN   Smith           NaN    France   Male
# freq            NaN           NaN      32           NaN      5014   5457
# mean     5000.50000  1.569094e+07     NaN    650.528800       NaN    NaN
# std      2886.89568  7.193619e+04     NaN     96.653299       NaN    NaN
# min         1.00000  1.556570e+07     NaN    350.000000       NaN    NaN
# 25%      2500.75000  1.562853e+07     NaN    584.000000       NaN    NaN
# 50%      5000.50000  1.569074e+07     NaN    652.000000       NaN    NaN
# 75%      7500.25000  1.575323e+07     NaN    718.000000       NaN    NaN
# max     10000.00000  1.581569e+07     NaN    850.000000       NaN    NaN
#
#                  Age        Tenure        Balance  NumOfProducts    HasCrCard  \
# ...

# %% [markdown]
# # Handling the Missing Values

# %%
df.isnull().sum() #There is no null values in the dataset
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Outliers

# %%
sns.boxplot(df['Balance']) # No outliers in Balance Column
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df['Age']) # there are outliers in Age column
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Categorical Columns and Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
le = LabelEncoder()

# %%
df['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Surname'].unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], dtype=object)

# %%
count(df['Geography'])
# Out:
# Counter({'France': 5014, 'Spain': 2477, 'Germany': 2509})

# %%
df['Geography'] = le.fit_transform(df['Geography'])
df['Gender'] = le.fit_transform(df['Gender'])
df['Surname'] = le.fit_transform(df['Surname'])

# %%
df.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115          619          0       0   42
# 1          2    15647311     1177          608          2       0   41
# 2          3    15619304     2040          502          0       0   42
# 3          4    15701354      289          699          0       0   39
# 4          5    15737888     1822          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # Dependant and Independant Variable

# %%
x = df.iloc[:,:-1] # Independant Variable
x.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115          619          0       0   42
# 1          2    15647311     1177          608          2       0   41
# 2          3    15619304     2040          502          0       0   42
# 3          4    15701354      289          699          0       0   39
# 4          5    15737888     1822          850          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4         79084.10

# %%
y = df['Exited']
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# # Scaling Independant Variables

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
st = StandardScaler()
nm = MinMaxScaler()

# %%
s_xtrain = st.fit_transform(xtrain)
s_xtrain
# Out:
# array([[-1.29671985,  0.57944472, -0.60566716, ..., -1.54167074,
#          0.9673886 , -0.85372045],
#        [ 0.12810842, -1.2259028 ,  0.22108595, ..., -1.54167074,
#          0.9673886 ,  0.07141614],
#        [-1.02887154, -0.17294697,  1.57856501, ..., -1.54167074,
#         -1.03371075,  0.1160741 ],
#        ...,
#        [ 0.7805772 ,  0.39462137, -0.38158287, ...,  0.64864693,
#          0.9673886 ,  0.61136515],
#        [ 0.06712355, -0.68585335, -1.04911819, ...,  0.64864693,
#         -1.03371075, -1.48546997],
#        [-0.42664597,  0.25658151,  0.18098665, ..., -1.54167074,
#          0.9673886 , -1.72784594]])

# %%
s_xtest = st.transform(xtest)
s_xtest
# Out:
# array([[-0.65915078, -0.50584615,  0.35553652, ...,  0.64864693,
#         -1.03371075,  0.569602  ],
#        [ 0.46664373, -0.19790466, -0.79672851, ...,  0.64864693,
#          0.9673886 , -0.44558951],
#        [ 1.27607924, -0.080758  ,  1.53492754, ..., -1.54167074,
#          0.9673886 , -1.37159305],
#        ...,
#        [-0.9838259 ,  1.2565875 ,  0.87446857, ..., -1.54167074,
#          0.9673886 , -0.65811806],
#        [ 1.05223706, -1.03068157,  1.15398424, ..., -1.54167074,
#         -1.03371075,  0.66715124],
#        [-0.03093735, -0.11942642,  1.47595799, ...,  0.64864693,
#         -1.03371075,  0.4454686 ]])

# %%
n_xtrain = nm.fit_transform(xtrain)
n_xtrain
# Out:
# array([[0.12642529, 0.66600394, 0.33879222, ..., 0.        , 1.        ,
#         0.25485714],
#        [0.53770754, 0.14715813, 0.57795974, ..., 0.        , 1.        ,
#         0.51955874],
#        [0.20374075, 0.44977118, 0.97065848, ..., 0.        , 0.        ,
#         0.53233635],
#        ...,
#        [0.72604521, 0.61288684, 0.40361651, ..., 1.        , 1.        ,
#         0.67404984],
#        [0.52010402, 0.30236503, 0.21050836, ..., 1.        , 0.        ,
#         0.07409993],
#        [0.37757552, 0.57321503, 0.5663596 , ..., 0.        , 1.        ,
#         0.00475092]])

# %%
n_xtest = nm.transform(xtest)
n_xtest
# Out:
# array([[0.31046209, 0.35409799, 0.61685432, ..., 1.        , 0.        ,
#         0.6621005 ],
#        [0.63542709, 0.44259849, 0.28352098, ..., 1.        , 1.        ,
#         0.37163224],
#        [0.86907381, 0.47626572, 0.9580348 , ..., 0.        , 1.        ,
#         0.10668258],
#        ...,
#        [0.21674335, 0.86061062, 0.76697373, ..., 0.        , 1.        ,
#         0.31082322],
#        [0.80446089, 0.20326351, 0.8478335 , ..., 0.        , 0.        ,
#         0.69001145],
#        [0.49179836, 0.46515265, 0.94097578, ..., 1.        , 0.        ,
#         0.62658325]])

# %% [markdown]
# # Training and Test Data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=11)

# %%
xtrain.count()
# Out:
# RowNumber          7000
# CustomerId         7000
# Surname            7000
# CreditScore        7000
# Geography          7000
# Gender             7000
# Age                7000
# Tenure             7000
# Balance            7000
# NumOfProducts      7000
# HasCrCard          7000
# IsActiveMember     7000
# EstimatedSalary    7000
# dtype: int64

# %%
xtest.count()
# Out:
# RowNumber          3000
# CustomerId         3000
# Surname            3000
# CreditScore        3000
# Geography          3000
# Gender             3000
# Age                3000
# Tenure             3000
# Balance            3000
# NumOfProducts      3000
# HasCrCard          3000
# IsActiveMember     3000
# EstimatedSalary    3000
# dtype: int64

# %%
ytrain.count()
# Out:
# 7000

# %%
ytest.count()
# Out:
# 3000
